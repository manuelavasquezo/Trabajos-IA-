# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelavasquezo/Trabajos-IA-/blob/main/Taller_Limpieza_Manuela_Vasquez_Dana_Mendoza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Taller Limpieza y transformación de datos**🧹

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en grupos de 3 o parejas.**

# %% [markdown]
# **Nombres estudiantes:**
#
# - Manuela Vásquez
# - Dana Melissa Mendoza

# %% [markdown]
# **Forma de entrega:**
#
# - Nombrar el archivo de la siguiente forma:“Taller_Limpieza_nombres_y_appellidos.ipynb”.
# - Suba el Jupyter Notebook a su cuenta en Github y envíe el link en el siguiente Forms: https://forms.office.com/r/6GZ89uiLNC.
#
# **IMPORTANTE:** No se recibirán talleres en Google Colab, el notebook debe estar subido en Github.

# %% [markdown]
# **Plazo de entrega:**
#
# 19 de marzo de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# Utilice la base de la GEIH de julio a diciembre de 2025, la cual se encuentra en https://drive.google.com/drive/folders/1Th4TWdsOahAAvBUKxixFhaELC_KPsl3y?usp=sharing. Tenga en cuenta sep="," y encoding='latin1'. Las variables 'DPTO' y 'RAMA4D_R4' deben ser cargadas como string.

# %% [markdown]
# # Ejercicio 1: Importar librerías y cargar datos

# %% [markdown]
# 1.	Importe todas las librerías que vaya a utilizar.

# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2.	Mejore la visualización de los dataframes como se ha visto en clase.

# %%
pd.options.display.max_columns = None
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# 3.	Conéctese a su Google Drive y establezca la ruta del dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 4.	Cargue los datos en el notebook. Llame al dataframe 'df_geih'

# %%
df_geih = pd.read_csv('/content/drive/MyDrive/datasets/GEIH_2025_Jul_Dic_Consolidado.csv', sep=",", encoding='latin1', dtype={'DPTO': str, 'RAMA4D_R4': str})
df_geih
# Out:
#          PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0       20250731    7  2025     8283143            1      1      1     10
# 1       20250731    7  2025     8283143            1      2      1     10
# 2       20250731    7  2025     8283145            1      1      1     10
# 3       20250731    7  2025     8283145            1      2      1     10
# 4       20250731    7  2025     8283145            1      3      1     10
# ...          ...  ...   ...         ...          ...    ...    ...    ...
# 409122  20251252   12  2025     8473907            1      1      1     10
# 409123  20251252   12  2025     8473908            1      1      1     10
# 409124  20251252   12  2025     8473908            1      2      1     10
# 409125  20251252   12  2025     8473908            1      3      1     10
# 409126  20251252   12  2025     8473908            1      4      1     10
#
#         AREA  CLASE  FEX_C18 DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# 0        NaN      2    27.75   08   1      1      1     72     8.00 1,952.00
# 1        NaN      2    27.75   08   1      2      2     34     8.00 1,990.00
# 2        NaN      2    59.11   08   1      1      1     45     6.00 1,980.00
# 3        NaN      2    59.11   08   1      2      2     50     2.00 1,975.00
# 4        NaN      2    59.11   08   1      3      1     19     6.00 2,006.00
# ...      ...    ...      ...  ...  ..    ...    ...    ...      ...      ...
# 409122   NaN      2   378.31   73   1      1      2     61     6.00 1,964.00
# 409123 54.00      1   534.55   54   1      1      1     58     3.00 1,967.00
# 409124 54.00      1   534.55   54   1      2      2     51     3.00 1,974.00
# 409125 54.00      1   534.55   54   1      3      2     31     2.00 1,994.00
# 409126 54.00      1   534.55   54   1      4      2     26     2.00 1,999.00
#
#         P6050  P6083  P6083S1  P6081  P6081S1  P2057  P2059  P2061  P6080  \
# 0           1      3      NaN      3      NaN      1    NaN      1      6
# 1           2      3      NaN      3      NaN      1    NaN      1      6
# 2           1      3      NaN      2      NaN      1    NaN      1      6
# 3           2      3      NaN      3      NaN      1    NaN      1      6
# 4           3      2      NaN      1     1.00      1    NaN      1      6
# ...       ...    ...      ...    ...      ...    ...    ...    ...    ...
# 409122      1      3      NaN      3      NaN      1    NaN      1      6
# 409123      1      3      NaN      3      NaN      2   2.00      2      6
# 409124      2      2      NaN      2      NaN      2   1.00      2      6
# 409125      3      1     2.00      1     1.00      2   2.00      2      6
# 409126      3      1     2.00      1     1.00      2   2.00      2      6
#
#        P6080S1  P6080S1A1  P6070  P6071  P6071S1  P6090  P6100  P6110  \
# 0          NaN        NaN   2.00   1.00     2.00      1   3.00    NaN
# 1          NaN        NaN   2.00   1.00     1.00      2    NaN    NaN
# 2          NaN        NaN   2.00   1.00     2.00      1   3.00    NaN
# 3          NaN        NaN   2.00   1.00     1.00      1   3.00    NaN
# 4          NaN        NaN   1.00   2.00      NaN      1   3.00    NaN
# ...        ...        ...    ...    ...      ...    ...    ...    ...
# 409122     NaN        NaN   3.00   2.00      NaN      1   1.00   5.00
# 409123     NaN        NaN   3.00   1.00     2.00      1   2.00   1.00
# 409124     NaN        NaN   3.00   1.00     1.00      1   1.00   1.00
# 409125     NaN        NaN   6.00    NaN      NaN      1   1.00   3.00
# 409126     NaN        NaN   6.00    NaN      NaN      1   3.00    NaN
#
#             P6120  P1906S1  P1906S2  P1906S3  P1906S4  P1906S5  P1906S6  \
# 0             NaN        4        4        4        3        3        4
# 1             NaN        4        4        4        4        4        4
# 2             NaN        4        4        4        4        4        4
# 3             NaN        4        4        4        4        4        4
# 4             NaN        4        4        4        4        4        4
# ...           ...      ...      ...      ...      ...      ...      ...
# 409122        NaN        4        4        3        4        4        4
# 409123 120,000.00        4        4        4        4        4        4
# 409124 318,240.00        4        4        4        4        4        4
# 409125 178,000.00        4        4        4        4        4        4
# 409126        NaN        4        4        4        4        4        4
#
#         P1906S7  P1906S8  P6160  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# 0             4        4   2.00   2.00    NaN   1.00     0.00      NaN    NaN
# 1             4        4   2.00   2.00    NaN   1.00     0.00      NaN    NaN
# 2             4        4   1.00   2.00    NaN   3.00     1.00      NaN    NaN
# 3             4        4   1.00   2.00    NaN   3.00     4.00      NaN    NaN
# 4             4        4   1.00   2.00    NaN   3.00     2.00      NaN    NaN
# ...         ...      ...    ...    ...    ...    ...      ...      ...    ...
# 409122        4        4   1.00   2.00    NaN   3.00     3.00      NaN    NaN
# 409123        4        4   1.00   1.00   2.00  13.00     9.00   111.00   9.00
# 409124        4        4   1.00   2.00    NaN  12.00     4.00   413.00   9.00
# 409125        4        4   1.00   2.00    NaN  10.00    10.00   719.00   7.00
# 409126        4        4   1.00   2.00    NaN  10.00    10.00   421.00   7.00
#
#         P3043S1  P3038  P3039  POB_MAY18  P4005  P4010  P4020  P4030S1  \
# 0           NaN   2.00   1.00       1.00      1      5      1        1
# 1           NaN   1.00   2.00       1.00      1      5      1        1
# 2           NaN   2.00   1.00       1.00      1      2      1        1
# 3           NaN   1.00   2.00       1.00      1      2      1        1
# 4           NaN   2.00   1.00       1.00      1      2      1        1
# ...         ...    ...    ...        ...    ...    ...    ...      ...
# 409122      NaN   1.00   2.00       1.00      1      1      4        1
# 409123   111.00   2.00   1.00       1.00      2      1      4        1
# 409124   413.00   1.00   2.00       1.00      2      1      4        1
# 409125   719.00   1.00   2.00       1.00      2      1      4        1
# 409126   421.00   1.00   2.00       1.00      2      1      4        1
#
#         P4030S1A1  P4030S2  P4030S3  P4030S4  P4030S4A1  P4030S5  P5000  \
# 0            1.00        2        2        2        NaN        2      2
# 1            1.00        2        2        2        NaN        2      2
# 2            1.00        2        2        2        NaN        2      3
# 3            1.00        2        2        2        NaN        2      3
# 4            1.00        2        2        2        NaN        2      3
# ...           ...      ...      ...      ...        ...      ...    ...
# 409122       2.00        2        2        2        NaN        1      4
# 409123       2.00        1        1        1       3.00        1      4
# 409124       2.00        1        1        1       3.00        1      4
# 409125       2.00        1        1        1       3.00        1      4
# 409126       2.00        1        1        1       3.00        1      4
#
#         P5010  P5020  P5030  P5040  P5050  P5070  P5080  P5090 P5090S1  P5100  \
# 0           1      6    NaN      4      6      5   5.00      4     NaN    NaN
# 1           1      6    NaN      4      6      5   5.00      4     NaN    NaN
# 2           2      6    NaN      4      6      5   5.00      4     NaN    NaN
# 3           2      6    NaN      4      6      5   5.00      4     NaN    NaN
# 4           2      6    NaN      4      6      5   5.00      4     NaN    NaN
# ...       ...    ...    ...    ...    ...    ...    ...    ...     ...    ...
# 409122      1      2   1.00      4      1      1   4.00      4     NaN    NaN
# 409123      3      1   1.00      1      1      1   3.00      1     NaN    NaN
# 409124      3      1   1.00      1      1      1   3.00      1     NaN    NaN
# 409125      3      1   1.00      1      1      1   3.00      1     NaN    NaN
# 409126      3      1   1.00      1      1      1   3.00      1     NaN    NaN
#
#                 P5110      P5130  P5140  P5222S1  P5222S10  P5222S11  P5222S2  \
# 0                 NaN 200,000.00    NaN      NaN       NaN       NaN      NaN
# 1                 NaN 200,000.00    NaN      NaN       NaN       NaN      NaN
# 2                 NaN 100,000.00    NaN      NaN       NaN       NaN      NaN
# 3                 NaN 100,000.00    NaN      NaN       NaN       NaN      NaN
# 4                 NaN 100,000.00    NaN      NaN       NaN       NaN      NaN
# ...               ...        ...    ...      ...       ...       ...      ...
# 409122            NaN 600,000.00    NaN      NaN       NaN       NaN      NaN
# 409123 300,000,000.00 700,000.00    NaN      NaN       NaN      1.00     1.00
# 409124 300,000,000.00 700,000.00    NaN      NaN       NaN      1.00     1.00
# 409125 300,000,000.00 700,000.00    NaN      NaN       NaN      1.00     1.00
# 409126 300,000,000.00 700,000.00    NaN      NaN       NaN      1.00     1.00
#
#         P5222S3  P5222S4  P5222S5  P5222S6  P5222S7  P5222S8 P5222S8A1  \
# 0           NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 1           NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 2           NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 3           NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 4           NaN      NaN      NaN      NaN      NaN      NaN       NaN
# ...         ...      ...      ...      ...      ...      ...       ...
# 409122      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 409123      NaN      NaN      NaN      NaN     1.00      NaN       NaN
# 409124      NaN      NaN      NaN      NaN     1.00      NaN       NaN
# 409125      NaN      NaN      NaN      NaN     1.00      NaN       NaN
# 409126      NaN      NaN      NaN      NaN     1.00      NaN       NaN
#
#         P5222S9  P6008  P70  FFT   FT  P3362S1  P3362S2  P3362S3  P3362S4  \
# 0          1.00      2    1  NaN 1.00      NaN      NaN      NaN      NaN
# 1          1.00      2    1 1.00  NaN      NaN      NaN      NaN      NaN
# 2          1.00      4    1  NaN 1.00      NaN      NaN      NaN      NaN
# 3          1.00      4    1 1.00  NaN      NaN      NaN      NaN      NaN
# 4          1.00      4    1  NaN 1.00      NaN      NaN      NaN      NaN
# ...         ...    ...  ...  ...  ...      ...      ...      ...      ...
# 409122     1.00      1    1  NaN 1.00      NaN      NaN      NaN      NaN
# 409123      NaN      4    1  NaN 1.00      NaN      NaN      NaN      NaN
# 409124      NaN      4    1  NaN 1.00      NaN      NaN      NaN      NaN
# 409125      NaN      4    1  NaN 1.00      NaN     1.00     1.00      NaN
# 409126      NaN      4    1  NaN 1.00      NaN      NaN      NaN      NaN
#
#         P3362S5  P3362S6  P3362S7 P3362S7A1  P3362S8  P6240  \
# 0           NaN      NaN      NaN       NaN      NaN   1.00
# 1           NaN      NaN      NaN       NaN      NaN   4.00
# 2           NaN      NaN      NaN       NaN      NaN   1.00
# 3           NaN      NaN      NaN       NaN      NaN   4.00
# 4           NaN      NaN      NaN       NaN      NaN   1.00
# ...         ...      ...      ...       ...      ...    ...
# 409122      NaN      NaN      NaN       NaN      NaN   1.00
# 409123      NaN      NaN      NaN       NaN      NaN   6.00
# 409124      NaN      NaN      NaN       NaN      NaN   1.00
# 409125      NaN      NaN      NaN       NaN      NaN   2.00
# 409126      NaN      NaN      NaN       NaN      NaN   6.00
#
#                         P6240S1  P6240S2  P6250  P6260  P6260S1 P6260S1A1  \
# 0                           NaN     1.00    NaN    NaN      NaN       NaN
# 1                           NaN      NaN   2.00   2.00      NaN       NaN
# 2                           NaN     1.00    NaN    NaN      NaN       NaN
# 3                           NaN      NaN   2.00   2.00      NaN       NaN
# 4                           NaN     1.00    NaN    NaN      NaN       NaN
# ...                         ...      ...    ...    ...      ...       ...
# 409122                      NaN     1.00    NaN    NaN      NaN       NaN
# 409123               VACACIONES      NaN   2.00   1.00     3.00       NaN
# 409124                      NaN     1.00    NaN    NaN      NaN       NaN
# 409125                      NaN      NaN   2.00   2.00      NaN       NaN
# 409126  DESCANSANDO EN SU HOGAR      NaN   2.00   1.00     5.00       NaN
#
#         P6260S2  P6270  P6280  P6300  P6310 P6310S1  P6320  P6330  P6340  \
# 0           NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# 1           NaN   2.00   2.00   2.00    NaN     NaN    NaN    NaN    NaN
# 2           NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# 3           NaN   2.00   2.00   1.00   9.00     NaN    NaN    NaN    NaN
# 4           NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# ...         ...    ...    ...    ...    ...     ...    ...    ...    ...
# 409122      NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# 409123      NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# 409124      NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
# 409125      NaN   2.00   1.00    NaN    NaN     NaN    NaN    NaN    NaN
# 409126     1.00    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN
#
#         P6350  P6351  PET      INGLABO  OCI  OFICIO_C8  P1800  P1800S1  \
# 0         NaN    NaN 1.00   790,000.00 1.00   9,212.00    NaN      NaN
# 1         NaN    NaN 1.00          NaN  NaN        NaN    NaN      NaN
# 2         NaN    NaN 1.00 1,100,000.00 1.00   1,311.00    NaN      NaN
# 3         NaN    NaN 1.00          NaN  NaN        NaN    NaN      NaN
# 4         NaN    NaN 1.00   820,000.00 1.00   9,212.00    NaN      NaN
# ...       ...    ...  ...          ...  ...        ...    ...      ...
# 409122    NaN    NaN 1.00 1,400,000.00 1.00   9,111.00    NaN      NaN
# 409123    NaN    NaN 1.00 3,000,000.00 1.00   2,330.00    NaN      NaN
# 409124    NaN    NaN 1.00 7,956,000.00 1.00   2,411.00    NaN      NaN
# 409125    NaN   1.00 1.00          NaN  NaN        NaN    NaN      NaN
# 409126    NaN    NaN 1.00   500,000.00 1.00   5,221.00   2.00      NaN
#
#         P1801S1  P1801S2  P1801S3  P1802  P1805  P1879  P1880 P1880S1  P1881  \
# 0           NaN      NaN      NaN    NaN    NaN    NaN   3.00     NaN   3.00
# 1           NaN      NaN      NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 2           NaN      NaN      NaN    NaN    NaN    NaN   7.00     NaN   3.00
# 3           NaN      NaN      NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 4           NaN      NaN      NaN    NaN    NaN    NaN   8.00     NaN   3.00
# ...         ...      ...      ...    ...    ...    ...    ...     ...    ...
# 409122      NaN      NaN      NaN    NaN    NaN    NaN   2.00     NaN  14.00
# 409123      NaN      NaN      NaN    NaN    NaN    NaN   8.00     NaN   8.00
# 409124      NaN      NaN      NaN    NaN    NaN    NaN   1.00     NaN   2.00
# 409125      NaN      NaN      NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 409126      NaN      NaN      NaN   3.00   2.00   1.00   3.00     NaN  14.00
#
#        P1881S1  P1882  P3044S2  P3045S1  P3045S2  P3045S3  P3046  P3047  \
# 0          NaN  10.00   143.00     2.00     2.00     2.00   2.00    NaN
# 1          NaN    NaN      NaN      NaN      NaN      NaN    NaN    NaN
# 2          NaN   4.00   141.00     2.00     2.00     2.00   2.00    NaN
# 3          NaN    NaN      NaN      NaN      NaN      NaN    NaN    NaN
# 4          NaN   3.00   141.00     2.00     2.00     2.00   2.00    NaN
# ...        ...    ...      ...      ...      ...      ...    ...    ...
# 409122     NaN    NaN 9,700.00     2.00     2.00     2.00   2.00    NaN
# 409123     NaN  30.00 8,530.00     2.00     1.00     2.00   1.00    NaN
# 409124     NaN  60.00 8,412.00     2.00     1.00     2.00   1.00    NaN
# 409125     NaN    NaN      NaN      NaN      NaN      NaN    NaN    NaN
# 409126     NaN    NaN 4,791.00      NaN      NaN      NaN    NaN   1.00
#
#         P3048  P3049  P3051      P3052  P3053  P3054  P3054S1  P3055  P3055S1  \
# 0         NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 1         NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 2         NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 3         NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 4         NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# ...       ...    ...    ...        ...    ...    ...      ...    ...      ...
# 409122    NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 409123    NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 409124    NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 409125    NaN    NaN    NaN        NaN    NaN    NaN      NaN    NaN      NaN
# 409126   1.00   1.00    NaN 700,000.00   1.00   2.00      NaN   2.00      NaN
#
#         P3056  P3057  P3058S1  P3058S2  P3058S3  P3058S4  P3058S5  P3059  \
# 0         NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 1         NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 2         NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 3         NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 4         NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# ...       ...    ...      ...      ...      ...      ...      ...    ...
# 409122    NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 409123    NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 409124    NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 409125    NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
# 409126    NaN    NaN      NaN      NaN      NaN      NaN      NaN    NaN
#
#         P3061  P3062S1  P3062S2  P3062S3  P3062S4  P3062S5  P3062S6  P3062S7  \
# 0         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 409122    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 409123    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 409124    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 409125    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 409126    NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         P3062S8  P3062S9  P3063  P3063S1  P3064  P3064S1  P3065  P3066  P3067  \
# 0           NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 1           NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 2           NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 3           NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 4           NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# ...         ...      ...    ...      ...    ...      ...    ...    ...    ...
# 409122      NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 409123      NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 409124      NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 409125      NaN      NaN    NaN      NaN    NaN      NaN    NaN    NaN    NaN
# 409126      NaN      NaN    NaN      NaN    NaN      NaN   2.00   2.00    NaN
#
#         P3067S1  P3067S2  P3068  P3069  P3071S3  P3072S2  P3073  P3363  P3364  \
# 0           NaN      NaN    NaN   2.00      NaN      NaN    NaN   1.00   2.00
# 1           NaN      NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 2           NaN      NaN    NaN   2.00      NaN      NaN    NaN   1.00   2.00
# 3           NaN      NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 4           NaN      NaN    NaN   2.00      NaN      NaN    NaN   1.00   2.00
# ...         ...      ...    ...    ...      ...      ...    ...    ...    ...
# 409122      NaN      NaN    NaN   1.00      NaN      NaN    NaN   1.00   2.00
# 409123      NaN      NaN    NaN  10.00      NaN      NaN    NaN   5.00   2.00
# 409124      NaN      NaN    NaN  10.00      NaN      NaN    NaN   1.00   1.00
# 409125      NaN      NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 409126      NaN      NaN    NaN   1.00      NaN      NaN   1.00    NaN    NaN
#
#          P3364S1  P3365  P3365S1  P514  P515  P550  P6400  P6410  P6420S2  \
# 0            NaN    NaN      NaN  1.00  1.00   NaN   1.00    NaN      NaN
# 1            NaN    NaN      NaN   NaN   NaN   NaN    NaN    NaN      NaN
# 2            NaN    NaN      NaN  1.00  1.00   NaN   1.00    NaN      NaN
# 3            NaN    NaN      NaN   NaN   NaN   NaN    NaN    NaN      NaN
# 4            NaN    NaN      NaN  1.00  1.00   NaN   1.00    NaN      NaN
# ...          ...    ...      ...   ...   ...   ...    ...    ...      ...
# 409122       NaN    NaN      NaN  1.00  1.00   NaN   1.00    NaN      NaN
# 409123       NaN    NaN      NaN  1.00  1.00   NaN   2.00   4.00 8,413.00
# 409124 79,600.00    NaN      NaN  1.00  1.00   NaN   1.00    NaN      NaN
# 409125       NaN    NaN      NaN   NaN   NaN   NaN    NaN    NaN      NaN
# 409126       NaN   2.00      NaN  2.00  1.00   NaN    NaN    NaN      NaN
#
#         P6422  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430 P6430S1  \
# 0        1.00     2.00     2.00     2.00     2.00  84.00   7.00     NaN
# 1         NaN      NaN      NaN      NaN      NaN    NaN    NaN     NaN
# 2        1.00     2.00     2.00     2.00     2.00  48.00   1.00     NaN
# 3         NaN      NaN      NaN      NaN      NaN    NaN    NaN     NaN
# 4        1.00     2.00     2.00     2.00     2.00  48.00   7.00     NaN
# ...       ...      ...      ...      ...      ...    ...    ...     ...
# 409122   2.00     2.00     2.00     2.00     2.00   1.00   3.00     NaN
# 409123   1.00     1.00     1.00     1.00     1.00  60.00   2.00     NaN
# 409124   1.00     1.00     1.00     1.00     1.00  23.00   2.00     NaN
# 409125    NaN      NaN      NaN      NaN      NaN    NaN    NaN     NaN
# 409126    NaN      NaN      NaN      NaN      NaN   4.00   4.00     NaN
#
#         P6440  P6450  P6460  P6460S1        P6500  P6510  P6510S1  P6510S2  \
# 0        1.00   1.00    NaN      NaN   590,000.00   2.00      NaN      NaN
# 1         NaN    NaN    NaN      NaN          NaN    NaN      NaN      NaN
# 2        1.00   1.00    NaN      NaN 1,000,000.00   2.00      NaN      NaN
# 3         NaN    NaN    NaN      NaN          NaN    NaN      NaN      NaN
# 4        1.00   1.00    NaN      NaN   720,000.00   2.00      NaN      NaN
# ...       ...    ...    ...      ...          ...    ...      ...      ...
# 409122   1.00   1.00    NaN      NaN   800,000.00   2.00      NaN      NaN
# 409123   1.00   2.00   1.00      NaN 3,000,000.00   2.00      NaN      NaN
# 409124   1.00   2.00   2.00    24.00 7,956,000.00   2.00      NaN      NaN
# 409125    NaN    NaN    NaN      NaN          NaN    NaN      NaN      NaN
# 409126   2.00    NaN    NaN      NaN          NaN    NaN      NaN      NaN
#
#         P6545  P6545S1  P6545S2  P6580  P6580S1  P6580S2  P6585S1  P6585S1A1  \
# 0        2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# 1         NaN      NaN      NaN    NaN      NaN      NaN      NaN        NaN
# 2        2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# 3         NaN      NaN      NaN    NaN      NaN      NaN      NaN        NaN
# 4        2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# ...       ...      ...      ...    ...      ...      ...      ...        ...
# 409122   2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# 409123   2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# 409124   2.00      NaN      NaN   2.00      NaN      NaN     2.00        NaN
# 409125    NaN      NaN      NaN    NaN      NaN      NaN      NaN        NaN
# 409126    NaN      NaN      NaN    NaN      NaN      NaN      NaN        NaN
#
#         P6585S1A2  P6585S2  P6585S2A1  P6585S2A2  P6585S3  P6585S3A1  \
# 0             NaN     2.00        NaN        NaN     2.00        NaN
# 1             NaN      NaN        NaN        NaN      NaN        NaN
# 2             NaN     2.00        NaN        NaN     2.00        NaN
# 3             NaN      NaN        NaN        NaN      NaN        NaN
# 4             NaN     2.00        NaN        NaN     2.00        NaN
# ...           ...      ...        ...        ...      ...        ...
# 409122        NaN     2.00        NaN        NaN     2.00        NaN
# 409123        NaN     2.00        NaN        NaN     2.00        NaN
# 409124        NaN     2.00        NaN        NaN     2.00        NaN
# 409125        NaN      NaN        NaN        NaN      NaN        NaN
# 409126        NaN      NaN        NaN        NaN      NaN        NaN
#
#         P6585S3A2  P6585S4  P6585S4A1  P6585S4A2  P6590  P6590S1  P6600  \
# 0             NaN     2.00        NaN        NaN   2.00      NaN   1.00
# 1             NaN      NaN        NaN        NaN    NaN      NaN    NaN
# 2             NaN     2.00        NaN        NaN   2.00      NaN   1.00
# 3             NaN      NaN        NaN        NaN    NaN      NaN    NaN
# 4             NaN     2.00        NaN        NaN   2.00      NaN   1.00
# ...           ...      ...        ...        ...    ...      ...    ...
# 409122        NaN     2.00        NaN        NaN   2.00      NaN   1.00
# 409123        NaN     2.00        NaN        NaN   2.00      NaN   2.00
# 409124        NaN     2.00        NaN        NaN   2.00      NaN   2.00
# 409125        NaN      NaN        NaN        NaN    NaN      NaN    NaN
# 409126        NaN      NaN        NaN        NaN    NaN      NaN    NaN
#
#           P6600S1  P6610  P6610S1  P6620  P6620S1  P6630S1    P6630S1A1  \
# 0      200,000.00   2.00      NaN   2.00      NaN     2.00          NaN
# 1             NaN    NaN      NaN    NaN      NaN      NaN          NaN
# 2      100,000.00   2.00      NaN   2.00      NaN     2.00          NaN
# 3             NaN    NaN      NaN    NaN      NaN      NaN          NaN
# 4      100,000.00   2.00      NaN   2.00      NaN     2.00          NaN
# ...           ...    ...      ...    ...      ...      ...          ...
# 409122 600,000.00   2.00      NaN   2.00      NaN     2.00          NaN
# 409123        NaN   2.00      NaN   2.00      NaN     1.00 1,500,000.00
# 409124        NaN   2.00      NaN   2.00      NaN     1.00 3,500,000.00
# 409125        NaN    NaN      NaN    NaN      NaN      NaN          NaN
# 409126        NaN    NaN      NaN    NaN      NaN      NaN          NaN
#
#         P6630S2    P6630S2A1  P6630S3    P6630S3A1  P6630S4  P6630S4A1  \
# 0          2.00          NaN     2.00          NaN     2.00        NaN
# 1           NaN          NaN      NaN          NaN      NaN        NaN
# 2          2.00          NaN     2.00          NaN     2.00        NaN
# 3           NaN          NaN      NaN          NaN      NaN        NaN
# 4          2.00          NaN     2.00          NaN     2.00        NaN
# ...         ...          ...      ...          ...      ...        ...
# 409122     2.00          NaN     2.00          NaN     2.00        NaN
# 409123     1.00 3,000,000.00     1.00 1,500,000.00     2.00        NaN
# 409124     1.00 7,956,000.00     2.00          NaN     2.00        NaN
# 409125      NaN          NaN      NaN          NaN      NaN        NaN
# 409126      NaN          NaN      NaN          NaN      NaN        NaN
#
#         P6630S6  P6630S6A1  P6640  P6640S1      P6750  P6760  P6765 P6765S1  \
# 0          2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# 1           NaN        NaN    NaN      NaN        NaN    NaN    NaN     NaN
# 2          2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# 3           NaN        NaN    NaN      NaN        NaN    NaN    NaN     NaN
# 4          2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# ...         ...        ...    ...      ...        ...    ...    ...     ...
# 409122     2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# 409123     2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# 409124     2.00        NaN   2.00      NaN        NaN    NaN    NaN     NaN
# 409125      NaN        NaN    NaN      NaN        NaN    NaN    NaN     NaN
# 409126      NaN        NaN    NaN      NaN 500,000.00    NaN   6.00     NaN
#
#         P6775  P6780 P6780S1  P6790  P6800  P6810 P6810S1  P6830 P6830S1  \
# 0         NaN    NaN     NaN  12.00  40.00    NaN     NaN    NaN     NaN
# 1         NaN    NaN     NaN    NaN    NaN    NaN     NaN    NaN     NaN
# 2         NaN    NaN     NaN  12.00  70.00    NaN     NaN    NaN     NaN
# 3         NaN    NaN     NaN    NaN    NaN    NaN     NaN    NaN     NaN
# 4         NaN    NaN     NaN  12.00  60.00    NaN     NaN    NaN     NaN
# ...       ...    ...     ...    ...    ...    ...     ...    ...     ...
# 409122    NaN    NaN     NaN   1.00  48.00    NaN     NaN    NaN     NaN
# 409123    NaN    NaN     NaN  12.00  30.00   2.00     NaN   3.00     NaN
# 409124    NaN    NaN     NaN  12.00  44.00    NaN     NaN    NaN     NaN
# 409125    NaN    NaN     NaN    NaN    NaN    NaN     NaN    NaN     NaN
# 409126    NaN   1.00     NaN  10.00  10.00   1.00     NaN   5.00     NaN
#
#         P6850  P6880 P6880S1  P6915 P6915S1  P6920  P6930  P6940  P6960  \
# 0       40.00   8.00     NaN   2.00     NaN   2.00    NaN    NaN    NaN
# 1         NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2       70.00   8.00     NaN   2.00     NaN   2.00    NaN    NaN    NaN
# 3         NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 4       60.00   8.00     NaN   2.00     NaN   2.00    NaN    NaN    NaN
# ...       ...    ...     ...    ...     ...    ...    ...    ...    ...
# 409122  48.00   1.00     NaN   3.00     NaN   2.00    NaN    NaN    NaN
# 409123   0.00   7.00     NaN   1.00     NaN   1.00   3.00   1.00  20.00
# 409124  44.00   7.00     NaN   1.00     NaN   1.00   2.00   1.00  10.00
# 409125    NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 409126   0.00   1.00     NaN   2.00     NaN   2.00    NaN    NaN    NaN
#
#         P6990  P7020  P7026  P7028 P7028S1  P7040  P7045  P7050  P7070  P7075  \
# 0        2.00   1.00   3.00   4.00     NaN   2.00    NaN    NaN    NaN    NaN
# 1         NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2        2.00   1.00  36.00   7.00     NaN   2.00    NaN    NaN    NaN    NaN
# 3         NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 4        2.00   1.00  18.00   7.00     NaN   2.00    NaN    NaN    NaN    NaN
# ...       ...    ...    ...    ...     ...    ...    ...    ...    ...    ...
# 409122   2.00   1.00   0.00   4.00     NaN   2.00    NaN    NaN    NaN    NaN
# 409123   1.00   1.00  48.00   4.00     NaN   2.00    NaN    NaN    NaN    NaN
# 409124   1.00   1.00  48.00   4.00     NaN   2.00    NaN    NaN    NaN    NaN
# 409125    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 409126   2.00   1.00   6.00   4.00     NaN   2.00    NaN    NaN    NaN    NaN
#
#         P7077  P7090  P7100  P7110  P7120  P7130  P7140S1  P7140S2  P7140S3  \
# 0         NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# 1         NaN    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN
# 2         NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# 3         NaN    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN
# 4         NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# ...       ...    ...    ...    ...    ...    ...      ...      ...      ...
# 409122    NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# 409123    NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# 409124    NaN   2.00    NaN    NaN    NaN   2.00      NaN      NaN      NaN
# 409125    NaN    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN
# 409126    NaN   1.00  44.00   2.00   2.00   1.00     1.00     1.00     1.00
#
#         P7140S4  P7140S5  P7140S6  P7140S7  P7140S8  P7140S9 P7140S9A1  P7150  \
# 0           NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 1           NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 2           NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 3           NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 4           NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# ...         ...      ...      ...      ...      ...      ...       ...    ...
# 409122      NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 409123      NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 409124      NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 409125      NaN      NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 409126     1.00     2.00     2.00     2.00     2.00     2.00       NaN   1.00
#
#         P7160  P7170S1  P7170S5  P7170S6  P7180  P7240 P7240S1  P760  P9440  \
# 0         NaN     1.00     1.00     1.00   2.00   3.00     NaN  0.00   2.00
# 1         NaN      NaN      NaN      NaN    NaN    NaN     NaN   NaN    NaN
# 2         NaN     1.00     2.00     1.00   2.00   8.00     NaN  1.00   2.00
# 3         NaN      NaN      NaN      NaN    NaN    NaN     NaN   NaN    NaN
# 4         NaN     1.00     2.00     1.00   2.00   3.00     NaN  1.00   2.00
# ...       ...      ...      ...      ...    ...    ...     ...   ...    ...
# 409122    NaN     1.00     1.00     1.00   2.00   3.00     NaN 72.00   2.00
# 409123    NaN     1.00     1.00     1.00   2.00   2.00     NaN  0.00   2.00
# 409124    NaN     1.00     1.00     1.00   2.00   2.00     NaN  4.00   2.00
# 409125    NaN      NaN      NaN      NaN    NaN    NaN     NaN   NaN    NaN
# 409126   1.00     1.00     2.00     1.00   2.00   2.00     NaN  0.00    NaN
#
#         P9450  RAMA2D_R4 RAMA4D_R4  \
# 0        2.00       1.00      0143
# 1         NaN        NaN       NaN
# 2        2.00       1.00      0141
# 3         NaN        NaN       NaN
# 4        2.00       1.00      0141
# ...       ...        ...       ...
# 409122   2.00      97.00      9700
# 409123   1.00      85.00      8530
# 409124   1.00      84.00      8412
# 409125    NaN        NaN       NaN
# 409126   2.00      47.00      4791
#
#                                          DESCRIPCION_CIIU         NOMBRE_DPTO
# 0                                 Cría de ovejas y cabras           ATLÁNTICO
# 1                                                     NaN           ATLÁNTICO
# 2                        Cría de ganado bovino y bufalino           ATLÁNTICO
# 3                                                     NaN           ATLÁNTICO
# 4                        Cría de ganado bovino y bufalino           ATLÁNTICO
# ...                                                   ...                 ...
# 409122  Actividades de los hogares individuales como e...              TOLIMA
# 409123  Establecimientos que combinan diferentes nivel...  NORTE DE SANTANDER
# 409124  Actividades ejecutivas de la administración pú...  NORTE DE SANTANDER
# 409125                                                NaN  NORTE DE SANTANDER
# 409126  Comercio al por menor realizado a través de in...  NORTE DE SANTANDER
#
# [409127 rows x 314 columns]

# %% [markdown]
# 5. Obtenga las dimensiones de la base

# %%
df_geih.shape
# Out:
# (409127, 314)

# %% [markdown]
# # Ejercicio 2:  Seleccionar y renombrar columnas

# %% [markdown]
# La GEIH contiene cientos de variables. Para nuestro análisis del mercado laboral, nos enfocaremos en un subconjunto.
#
# Adicionalmente, los nombres de las columnas en la GEIH son códigos. Para hacer el análisis más intuitivo, vamos a renombrarlas.

# %% [markdown]
# 1. Crea un nuevo DataFrame llamado `df_empleo` que contenga únicamente las columnas que están en la lista `columnas_interes`.

# %%
columnas_interes = ['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'MES', 'CLASE', 'DPTO', 'FEX_C18', 'PT', 'P3271', 'P6040', 'P6080', 'P3043', 'OCI',
                    'P6430', 'RAMA4D_R4', 'INGLABO', 'DESCRIPCION_CIIU', 'NOMBRE_DPTO']

# %%
df_empleo = df_geih[columnas_interes]
df_empleo
# Out:
#         DIRECTORIO  SECUENCIA_P  ORDEN  MES  CLASE DPTO  FEX_C18  PT  P3271  \
# 0          8283143            1      1    7      2   08    27.75   1      1
# 1          8283143            1      2    7      2   08    27.75   1      2
# 2          8283145            1      1    7      2   08    59.11   1      1
# 3          8283145            1      2    7      2   08    59.11   1      2
# 4          8283145            1      3    7      2   08    59.11   1      1
# ...            ...          ...    ...  ...    ...  ...      ...  ..    ...
# 409122     8473907            1      1   12      2   73   378.31   1      2
# 409123     8473908            1      1   12      1   54   534.55   1      1
# 409124     8473908            1      2   12      1   54   534.55   1      2
# 409125     8473908            1      3   12      1   54   534.55   1      2
# 409126     8473908            1      4   12      1   54   534.55   1      2
#
#         P6040  P6080  P3043  OCI  P6430 RAMA4D_R4      INGLABO  \
# 0          72      6    NaN 1.00   7.00      0143   790,000.00
# 1          34      6    NaN  NaN    NaN       NaN          NaN
# 2          45      6    NaN 1.00   1.00      0141 1,100,000.00
# 3          50      6    NaN  NaN    NaN       NaN          NaN
# 4          19      6    NaN 1.00   7.00      0141   820,000.00
# ...       ...    ...    ...  ...    ...       ...          ...
# 409122     61      6    NaN 1.00   3.00      9700 1,400,000.00
# 409123     58      6   9.00 1.00   2.00      8530 3,000,000.00
# 409124     51      6   9.00 1.00   2.00      8412 7,956,000.00
# 409125     31      6   7.00  NaN    NaN       NaN          NaN
# 409126     26      6   7.00 1.00   4.00      4791   500,000.00
#
#                                          DESCRIPCION_CIIU         NOMBRE_DPTO
# 0                                 Cría de ovejas y cabras           ATLÁNTICO
# 1                                                     NaN           ATLÁNTICO
# 2                        Cría de ganado bovino y bufalino           ATLÁNTICO
# 3                                                     NaN           ATLÁNTICO
# 4                        Cría de ganado bovino y bufalino           ATLÁNTICO
# ...                                                   ...                 ...
# 409122  Actividades de los hogares individuales como e...              TOLIMA
# 409123  Establecimientos que combinan diferentes nivel...  NORTE DE SANTANDER
# 409124  Actividades ejecutivas de la administración pú...  NORTE DE SANTANDER
# 409125                                                NaN  NORTE DE SANTANDER
# 409126  Comercio al por menor realizado a través de in...  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# 2. Renombra las columnas del DataFrame `df_empleo` utilizando el diccionario `mapa_nombres`.

# %%
mapa_nombres = {
'DIRECTORIO': 'id_vivienda',
'SECUENCIA_P': 'id_hogar',
'ORDEN': 'id_persona',
'MES': 'mes',
'CLASE': 'clase',
'DPTO': 'departamento',
'FEX_C18': 'factor_expansion',
'PT': 'poblacion_total',
'P3271': 'sexo',
'P6040': 'edad',
'P6080': 'grupo_etnico',
'P3043': 'nivel_educativo',
'OCI': 'ocupados',
'P6430': 'categoria_ocupacional',
'RAMA4D_R4': 'cod_ciiu',
'INGLABO': 'ingreso_laboral',
'DESCRIPCION_CIIU': 'desc_ciiu',
'NOMBRE_DPTO': 'nombre_dpto'}

# %%
df_empleo.rename(columns=mapa_nombres, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase departamento  \
# 0           8283143         1           1    7      2           08
# 1           8283143         1           2    7      2           08
# 2           8283145         1           1    7      2           08
# 3           8283145         1           2    7      2           08
# 4           8283145         1           3    7      2           08
# ...             ...       ...         ...  ...    ...          ...
# 409122      8473907         1           1   12      2           73
# 409123      8473908         1           1   12      1           54
# 409124      8473908         1           2   12      1           54
# 409125      8473908         1           3   12      1           54
# 409126      8473908         1           4   12      1           54
#
#         factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0                  27.75                1     1    72             6
# 1                  27.75                1     2    34             6
# 2                  59.11                1     1    45             6
# 3                  59.11                1     2    50             6
# 4                  59.11                1     1    19             6
# ...                  ...              ...   ...   ...           ...
# 409122            378.31                1     2    61             6
# 409123            534.55                1     1    58             6
# 409124            534.55                1     2    51             6
# 409125            534.55                1     2    31             6
# 409126            534.55                1     2    26             6
#
#         nivel_educativo  ocupados  categoria_ocupacional cod_ciiu  \
# 0                   NaN      1.00                   7.00     0143
# 1                   NaN       NaN                    NaN      NaN
# 2                   NaN      1.00                   1.00     0141
# 3                   NaN       NaN                    NaN      NaN
# 4                   NaN      1.00                   7.00     0141
# ...                 ...       ...                    ...      ...
# 409122              NaN      1.00                   3.00     9700
# 409123             9.00      1.00                   2.00     8530
# 409124             9.00      1.00                   2.00     8412
# 409125             7.00       NaN                    NaN      NaN
# 409126             7.00      1.00                   4.00     4791
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                   NaN                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                   NaN                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125              NaN                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# 3. Obtenga las dimensiones de la base

# %%
df_empleo.shape
# Out:
# (409127, 18)

# %% [markdown]
# # Ejercicio 3: Revisión de duplicados

# %% [markdown]
# Un paso crucial en la limpieza es asegurar que no haya observaciones duplicadas que puedan sesgar nuestro análisis.

# %% [markdown]
# 1. Verifica si hay filas duplicadas en `df_empleo`.

# %%
df_empleo.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 409122    False
# 409123    False
# 409124    False
# 409125    False
# 409126    False
# Length: 409127, dtype: bool

# %% [markdown]
# 2. Cuenta cuántas filas duplicadas existen.

# %%
df_empleo.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 3. Elimina las filas duplicadas, si las hay.

# %%
#no hay filas duplicadas

# %% [markdown]
# 4. Verifica si hay filas duplicadas específicamente en las columnas 'id_vivienda', 'id_hogar', 'id_persona'.

# %%
df_empleo.duplicated(subset=['id_vivienda', 'id_hogar', 'id_persona']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Ejercicio 4: Valores faltantes

# %% [markdown]
# Los datos del mundo real raramente están completos. Aquí, trataremos los valores faltantes en la columna de ingresos.

# %% [markdown]
# 1. Calcula el número de valores nulos (`NaN`) en la columna `ingreso_laboral` **antes** de cualquier modificación.

# %%
df_empleo['ingreso_laboral'].isna().sum()
# Out:
# np.int64(231144)

# %% [markdown]
# 2. En la GEIH, un ingreso faltante a menudo significa que la persona no reportó ingresos o no aplica (ej. no trabaja). Una estrategia común es imputar estos valores con `0`. Rellena los valores `NaN` en la columna `ingreso_laboral` con `0`.

# %%
df_empleo['ingreso_laboral'].fillna(0, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase departamento  \
# 0           8283143         1           1    7      2           08
# 1           8283143         1           2    7      2           08
# 2           8283145         1           1    7      2           08
# 3           8283145         1           2    7      2           08
# 4           8283145         1           3    7      2           08
# ...             ...       ...         ...  ...    ...          ...
# 409122      8473907         1           1   12      2           73
# 409123      8473908         1           1   12      1           54
# 409124      8473908         1           2   12      1           54
# 409125      8473908         1           3   12      1           54
# 409126      8473908         1           4   12      1           54
#
#         factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0                  27.75                1     1    72             6
# 1                  27.75                1     2    34             6
# 2                  59.11                1     1    45             6
# 3                  59.11                1     2    50             6
# 4                  59.11                1     1    19             6
# ...                  ...              ...   ...   ...           ...
# 409122            378.31                1     2    61             6
# 409123            534.55                1     1    58             6
# 409124            534.55                1     2    51             6
# 409125            534.55                1     2    31             6
# 409126            534.55                1     2    26             6
#
#         nivel_educativo  ocupados  categoria_ocupacional cod_ciiu  \
# 0                   NaN      1.00                   7.00     0143
# 1                   NaN       NaN                    NaN      NaN
# 2                   NaN      1.00                   1.00     0141
# 3                   NaN       NaN                    NaN      NaN
# 4                   NaN      1.00                   7.00     0141
# ...                 ...       ...                    ...      ...
# 409122              NaN      1.00                   3.00     9700
# 409123             9.00      1.00                   2.00     8530
# 409124             9.00      1.00                   2.00     8412
# 409125             7.00       NaN                    NaN      NaN
# 409126             7.00      1.00                   4.00     4791
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 5: Decodificar variables

# %% [markdown]
# Las variables categóricas a menudo necesitan ser "traducidas" para hacerlas más entendibles para el análisis.

# %% [markdown]
# 1. Usa los siguientes diccionarios para reemplazar los códigos numéricos por etiquetas de texto en las siguientes columnas: 'clase', 'sexo', 'grupo_etnico', 'nivel_educativo' y 'categoria_ocupacional'. Muestra los conteos de las nuevas categorías usando `.value_counts()` para verificar el cambio en cada una de las columnas.

# %%
dic_clase = {1: 'Cabeceras', 2: 'Centros poblados y rural disperso'}
dic_sexo = {1: 'Hombre', 2: 'Mujer'}
dic_etnico = {1: 'Indígena', 2: 'Gitano (Rom)', 3: 'Raizal del archipiélago', 4: 'Palenquero',
              5: 'Negro, mulato (afrodescendiente)', 6: 'Ninguno de los anteriores'}
dic_nivel_educativo = {1: 'Ninguno', 2: 'Educación media', 3: 'Educación media',
                       4: 'Educación media', 5: 'Técnica profesional', 6: 'Tecnológica',
                       7: 'Universitaria', 8: 'Especialización', 9: 'Maestría',
                       10: 'Doctorado', 99: 'No sabe, no informa'}
dic_cat_ocu = {1: 'Asalariado', 2: 'Asalariado', 3: 'Asalariado',
               8: 'Asalariado', 4: 'Independiente', 5: 'Independiente',
               9: 'Independiente', 6: 'Trabajador sin remuneración',
               7: 'Trabajador sin remuneración'}

# %%
df_empleo['clase'].replace(dic_clase, inplace=True)

# %%
df_empleo['sexo'].replace(dic_sexo, inplace=True)

# %%
df_empleo['grupo_etnico'].replace(dic_etnico, inplace=True)

# %%
df_empleo['nivel_educativo'].replace(dic_nivel_educativo, inplace=True)

# %%
df_empleo['categoria_ocupacional'].replace(dic_cat_ocu, inplace=True)

# %%
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase departamento  factor_expansion  \
# 0       Centros poblados y rural disperso           08             27.75
# 1       Centros poblados y rural disperso           08             27.75
# 2       Centros poblados y rural disperso           08             59.11
# 3       Centros poblados y rural disperso           08             59.11
# 4       Centros poblados y rural disperso           08             59.11
# ...                                   ...          ...               ...
# 409122  Centros poblados y rural disperso           73            378.31
# 409123                          Cabeceras           54            534.55
# 409124                          Cabeceras           54            534.55
# 409125                          Cabeceras           54            534.55
# 409126                          Cabeceras           54            534.55
#
#         poblacion_total    sexo  edad               grupo_etnico  \
# 0                     1  Hombre    72  Ninguno de los anteriores
# 1                     1   Mujer    34  Ninguno de los anteriores
# 2                     1  Hombre    45  Ninguno de los anteriores
# 3                     1   Mujer    50  Ninguno de los anteriores
# 4                     1  Hombre    19  Ninguno de los anteriores
# ...                 ...     ...   ...                        ...
# 409122                1   Mujer    61  Ninguno de los anteriores
# 409123                1  Hombre    58  Ninguno de los anteriores
# 409124                1   Mujer    51  Ninguno de los anteriores
# 409125                1   Mujer    31  Ninguno de los anteriores
# 409126                1   Mujer    26  Ninguno de los anteriores
#
#        nivel_educativo  ocupados        categoria_ocupacional cod_ciiu  \
# 0                  NaN      1.00  Trabajador sin remuneración     0143
# 1                  NaN       NaN                          NaN      NaN
# 2                  NaN      1.00                   Asalariado     0141
# 3                  NaN       NaN                          NaN      NaN
# 4                  NaN      1.00  Trabajador sin remuneración     0141
# ...                ...       ...                          ...      ...
# 409122             NaN      1.00                   Asalariado     9700
# 409123        Maestría      1.00                   Asalariado     8530
# 409124        Maestría      1.00                   Asalariado     8412
# 409125   Universitaria       NaN                          NaN      NaN
# 409126   Universitaria      1.00                Independiente     4791
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 6: Reorganizar columnas

# %% [markdown]
# 1. Reorganiza las columnas con el siguiente orden: 'id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto',     'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo', 'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral'

# %%
df_empleo=df_empleo[['id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto',
                     'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo',
                     'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral']
                    ]

# %%
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase departamento         nombre_dpto  \
# 0       Centros poblados y rural disperso           08           ATLÁNTICO
# 1       Centros poblados y rural disperso           08           ATLÁNTICO
# 2       Centros poblados y rural disperso           08           ATLÁNTICO
# 3       Centros poblados y rural disperso           08           ATLÁNTICO
# 4       Centros poblados y rural disperso           08           ATLÁNTICO
# ...                                   ...          ...                 ...
# 409122  Centros poblados y rural disperso           73              TOLIMA
# 409123                          Cabeceras           54  NORTE DE SANTANDER
# 409124                          Cabeceras           54  NORTE DE SANTANDER
# 409125                          Cabeceras           54  NORTE DE SANTANDER
# 409126                          Cabeceras           54  NORTE DE SANTANDER
#
#         factor_expansion  poblacion_total    sexo  edad  \
# 0                  27.75                1  Hombre    72
# 1                  27.75                1   Mujer    34
# 2                  59.11                1  Hombre    45
# 3                  59.11                1   Mujer    50
# 4                  59.11                1  Hombre    19
# ...                  ...              ...     ...   ...
# 409122            378.31                1   Mujer    61
# 409123            534.55                1  Hombre    58
# 409124            534.55                1   Mujer    51
# 409125            534.55                1   Mujer    31
# 409126            534.55                1   Mujer    26
#
#                      grupo_etnico nivel_educativo  ocupados  \
# 0       Ninguno de los anteriores             NaN      1.00
# 1       Ninguno de los anteriores             NaN       NaN
# 2       Ninguno de los anteriores             NaN      1.00
# 3       Ninguno de los anteriores             NaN       NaN
# 4       Ninguno de los anteriores             NaN      1.00
# ...                           ...             ...       ...
# 409122  Ninguno de los anteriores             NaN      1.00
# 409123  Ninguno de los anteriores        Maestría      1.00
# 409124  Ninguno de los anteriores        Maestría      1.00
# 409125  Ninguno de los anteriores   Universitaria       NaN
# 409126  Ninguno de los anteriores   Universitaria      1.00
#
#               categoria_ocupacional cod_ciiu  \
# 0       Trabajador sin remuneración     0143
# 1                               NaN      NaN
# 2                        Asalariado     0141
# 3                               NaN      NaN
# 4       Trabajador sin remuneración     0141
# ...                             ...      ...
# 409122                   Asalariado     9700
# 409123                   Asalariado     8530
# 409124                   Asalariado     8412
# 409125                          NaN      NaN
# 409126                Independiente     4791
#
#                                                 desc_ciiu  ingreso_laboral
# 0                                 Cría de ovejas y cabras       790,000.00
# 1                                                     NaN             0.00
# 2                        Cría de ganado bovino y bufalino     1,100,000.00
# 3                                                     NaN             0.00
# 4                        Cría de ganado bovino y bufalino       820,000.00
# ...                                                   ...              ...
# 409122  Actividades de los hogares individuales como e...     1,400,000.00
# 409123  Establecimientos que combinan diferentes nivel...     3,000,000.00
# 409124  Actividades ejecutivas de la administración pú...     7,956,000.00
# 409125                                                NaN             0.00
# 409126  Comercio al por menor realizado a través de in...       500,000.00
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 7: Cambiar tipo de dato

# %% [markdown]
# Para realizar cálculos y análisis correctamente, las columnas deben tener el tipo de dato adecuado (numérico, categórico, etc.).

# %% [markdown]
# 1.  Muestra en pantalla los tipos de datos actuales de `df_empleo`.

# %%
df_empleo.dtypes
# Out:
# id_vivienda                int64
# id_hogar                   int64
# id_persona                 int64
# mes                        int64
# clase                     object
# departamento              object
# nombre_dpto               object
# factor_expansion         float64
# poblacion_total            int64
# sexo                      object
# edad                       int64
# grupo_etnico              object
# nivel_educativo           object
# ocupados                 float64
# categoria_ocupacional     object
# cod_ciiu                  object
# desc_ciiu                 object
# ingreso_laboral          float64
# dtype: object

# %% [markdown]
# 2.  Las siguientes columnas representan categorías: 'clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu'. Conviértelas al tipo `category` para optimizar el uso de memoria y facilitar análisis futuros.

# %%
df_empleo[['clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico',
           'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu']
          ] = df_empleo[['clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico',
                         'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu']].astype('category')
df_empleo.dtypes
# Out:
# id_vivienda                 int64
# id_hogar                    int64
# id_persona                  int64
# mes                         int64
# clase                    category
# departamento             category
# nombre_dpto              category
# factor_expansion          float64
# poblacion_total             int64
# sexo                     category
# edad                        int64
# grupo_etnico             category
# nivel_educativo          category
# ocupados                  float64
# categoria_ocupacional    category
# cod_ciiu                 category
# desc_ciiu                category
# ingreso_laboral           float64
# dtype: object

# %% [markdown]
# # Ejercicio 8: Ordenar el dataframe (5%)

# %% [markdown]
# 1. Ordena el dataframe por la columna "edad" de mayor a menor. Observa la columna 'edad' y escribe en una celda de markdown cuál fue la edad mínima y la edad máxima de las personas que respondieron la encuesta de la GEIH.

# %%
df_empleo=df_empleo.sort_values(by='edad', ascending=False)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 256896      8395695         1           1   10
# 5135        8286476         1           5    7
# 32904       8299104         1           3    7
# 256662      8395585         1           3   10
# 396633      8468208         1           4   12
# ...             ...       ...         ...  ...
# 245532      8391286         1           5   10
# 145507      8348957         1           4    9
# 185317      8365558         1           3    9
# 366733      8446239         1           6   12
# 289156      8409467         1           3   11
#
#                                     clase departamento   nombre_dpto  \
# 256896                          Cabeceras           18       CAQUETÁ
# 5135                            Cabeceras           27         CHOCÓ
# 32904   Centros poblados y rural disperso           13       BOLÍVAR
# 256662                          Cabeceras           17        CALDAS
# 396633  Centros poblados y rural disperso           25  CUNDINAMARCA
# ...                                   ...          ...           ...
# 245532                          Cabeceras           63       QUINDÍO
# 145507                          Cabeceras           50          META
# 185317                          Cabeceras           85      CASANARE
# 366733                          Cabeceras           08     ATLÁNTICO
# 289156                          Cabeceras           27         CHOCÓ
#
#         factor_expansion  poblacion_total    sexo  edad  \
# 256896             40.61                1   Mujer   108
# 5135               31.65                1   Mujer   108
# 32904             128.58                1   Mujer   106
# 256662             66.42                1   Mujer   106
# 396633          1,231.96                1   Mujer   106
# ...                  ...              ...     ...   ...
# 245532            151.42                1   Mujer     0
# 145507            241.71                1  Hombre     0
# 185317            299.88                1   Mujer     0
# 366733          1,371.41                1  Hombre     0
# 289156             52.89                1   Mujer     0
#
#                             grupo_etnico nivel_educativo  ocupados  \
# 256896         Ninguno de los anteriores             NaN       NaN
# 5135    Negro, mulato (afrodescendiente)             NaN       NaN
# 32904   Negro, mulato (afrodescendiente)             NaN       NaN
# 256662         Ninguno de los anteriores             NaN       NaN
# 396633         Ninguno de los anteriores             NaN       NaN
# ...                                  ...             ...       ...
# 245532         Ninguno de los anteriores             NaN       NaN
# 145507         Ninguno de los anteriores             NaN       NaN
# 185317         Ninguno de los anteriores             NaN       NaN
# 366733         Ninguno de los anteriores             NaN       NaN
# 289156  Negro, mulato (afrodescendiente)             NaN       NaN
#
#        categoria_ocupacional cod_ciiu desc_ciiu  ingreso_laboral
# 256896                   NaN      NaN       NaN             0.00
# 5135                     NaN      NaN       NaN             0.00
# 32904                    NaN      NaN       NaN             0.00
# 256662                   NaN      NaN       NaN             0.00
# 396633                   NaN      NaN       NaN             0.00
# ...                      ...      ...       ...              ...
# 245532                   NaN      NaN       NaN             0.00
# 145507                   NaN      NaN       NaN             0.00
# 185317                   NaN      NaN       NaN             0.00
# 366733                   NaN      NaN       NaN             0.00
# 289156                   NaN      NaN       NaN             0.00
#
# [409127 rows x 18 columns]

# %% [markdown]
# Escribe tu análisis aquí: la edad mínima es de 0 años y la edad máxima es de 108 años

# %% [markdown]
# # Ejercicio 9: Groupby

# %% [markdown]
# Agrupar los datos por categorías, nos permite realizar análisis más profundos y obtener insights valiosos, que a simple vista no vemos en la base de datos.

# %% [markdown]
# 1. Crea un nuevo dataframe llamado "df_sexo" donde se agrupe por 'sexo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de sexo en una columna.

# %%
df_sexo = df_empleo.groupby('sexo')[['poblacion_total', 'ocupados']].sum().reset_index()
df_sexo['porcentaje_ocupados'] = df_sexo['ocupados'] / df_sexo['poblacion_total']
df_sexo
# Out:
#      sexo  poblacion_total   ocupados  porcentaje_ocupados
# 0  Hombre           190530 100,790.00                 0.53
# 1   Mujer           218597  81,063.00                 0.37

# %% [markdown]
# 2. Crea un nuevo dataframe llamado "df_educacion" donde se agrupe por 'nivel_educativo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de nivel educativo en una columna.

# %%
df_educacion = df_empleo.groupby('nivel_educativo')[['poblacion_total', 'ocupados']].sum().reset_index()
df_educacion['porcentaje_ocupados'] = df_educacion['ocupados'] / df_educacion['poblacion_total']
df_educacion
# Out:
#        nivel_educativo  poblacion_total  ocupados  porcentaje_ocupados
# 0            Doctorado              339    294.00                 0.87
# 1      Educación media           116635 66,945.00                 0.57
# 2      Especialización             7927  6,269.00                 0.79
# 3             Maestría             3154  2,701.00                 0.86
# 4              Ninguno            12963  2,539.00                 0.20
# 5  No sabe, no informa                1      1.00                 1.00
# 6          Tecnológica            10640  7,928.00                 0.75
# 7  Técnica profesional            24503 16,989.00                 0.69
# 8        Universitaria            32517 23,461.00                 0.72

# %% [markdown]
# 3. En una celda de Markdown escribe qué conclusiones puedes sacar de la información obtenida en df_sexo y df_educacion.

# %% [markdown]
# Escribe tu análisis aquí: Se observa de los datos que hay una marcada segmentación en el mercado laboral, el porcentaje de ocupados es mayor en hombres con un 57% y en mujeres de 37% a pesar de presentar un mayor volumen poblacional respecto a los hombres.
# Por otro lado, en cuanto a los niveles educativos, se demuestra una correlación positiva y robusta entre el nivel de capital humano y la probabilidad de trabajo (analizándolo desde el porcentaje de ocupados). Se observa que el acceso a educación de niveles de posgrado como maestría y doctorado, garantiza tasas de ocupados mas elevadas (86% y 87% respectivamente). En contraste a esta situación, la población que no cuenta con ningún nivel de educación representa solo una tasa de ocupación del 20%. Adicionalmente se observa que los otros niveles de educación, presentan tasas de ocupación superiores al 57%.

# %% [markdown]
# # Ejercicio 10: Filtrar datos

# %% [markdown]
# 1. A partir de df_empleo, crea el DataFrame `df_ing` con observaciones donde `ingreso_laboral` no sea nulo y además sea mayor estrictamente al salario mínimo para 2026 (con subsidio de transporte).

# %%
df_ing = df_empleo[df_empleo['ingreso_laboral'].notnull() & (df_empleo['ingreso_laboral'] > 2000000)]
df_ing
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 9434        8289133         1           1    7
# 386896      8463890         1           1   12
# 396         8283438         1           2    7
# 67691       8316408         1           1    7
# 402398      8470477         1           1   12
# ...             ...       ...         ...  ...
# 366305      8446086         1           4   12
# 149860      8350784         1           2    9
# 231294      8385185         1           1   10
# 329307      8430330         1           2   11
# 72203       8318346         1           5    8
#
#                                     clase departamento  \
# 9434                            Cabeceras           73
# 386896                          Cabeceras           17
# 396                             Cabeceras           05
# 67691                           Cabeceras           88
# 402398                          Cabeceras           05
# ...                                   ...          ...
# 366305                          Cabeceras           05
# 149860                          Cabeceras           76
# 231294  Centros poblados y rural disperso           18
# 329307  Centros poblados y rural disperso           73
# 72203                           Cabeceras           18
#
#                                               nombre_dpto  factor_expansion  \
# 9434                                               TOLIMA            194.61
# 386896                                             CALDAS            213.09
# 396                                             ANTIOQUIA          2,546.84
# 67691   ARCHIPIÉLAGO DE SAN ANDRÉS, PROVIDENCIA Y SANT...             20.83
# 402398                                          ANTIOQUIA            693.35
# ...                                                   ...               ...
# 366305                                          ANTIOQUIA            863.65
# 149860                                    VALLE DEL CAUCA            823.54
# 231294                                            CAQUETÁ            403.95
# 329307                                             TOLIMA          1,860.81
# 72203                                             CAQUETÁ             49.71
#
#         poblacion_total    sexo  edad               grupo_etnico  \
# 9434                  1  Hombre    87  Ninguno de los anteriores
# 386896                1   Mujer    87  Ninguno de los anteriores
# 396                   1  Hombre    86  Ninguno de los anteriores
# 67691                 1  Hombre    86  Ninguno de los anteriores
# 402398                1  Hombre    86  Ninguno de los anteriores
# ...                 ...     ...   ...                        ...
# 366305                1  Hombre    17  Ninguno de los anteriores
# 149860                1   Mujer    17  Ninguno de los anteriores
# 231294                1  Hombre    16  Ninguno de los anteriores
# 329307                1  Hombre    16  Ninguno de los anteriores
# 72203                 1   Mujer    16  Ninguno de los anteriores
#
#         nivel_educativo  ocupados categoria_ocupacional cod_ciiu  \
# 9434    Educación media      1.00         Independiente     4530
# 386896              NaN      1.00         Independiente     5611
# 396         Tecnológica      1.00            Asalariado     5511
# 67691               NaN      1.00         Independiente     4711
# 402398    Universitaria      1.00            Asalariado     9491
# ...                 ...       ...                   ...      ...
# 366305              NaN      1.00            Asalariado     5611
# 149860              NaN      1.00         Independiente     5619
# 231294              NaN      1.00            Asalariado     0141
# 329307              NaN      1.00         Independiente     0123
# 72203               NaN      1.00            Asalariado     9700
#
#                                                 desc_ciiu  ingreso_laboral
# 9434    Comercio de partes, piezas (autopartes) y acce...     3,000,000.00
# 386896           Expendio a la mesa de comidas preparadas     3,200,000.00
# 396                                Alojamiento en hoteles     3,000,000.00
# 67691   Comercio al por menor en establecimientos no e...     3,000,000.00
# 402398             Actividades de asociaciones religiosas     2,400,000.00
# ...                                                   ...              ...
# 366305           Expendio a la mesa de comidas preparadas     2,700,000.00
# 149860  Otros tipos de expendio de comidas preparadas ...     2,400,000.00
# 231294                   Cría de ganado bovino y bufalino    16,250,000.00
# 329307                                    Cultivo de café     2,765,000.00
# 72203   Actividades de los hogares individuales como e...     2,300,000.00
#
# [38093 rows x 18 columns]

# %% [markdown]
# 2. ¿Cuántas personas tienen un salario estrictamente mayor al salario mínimo?

# %%
len(df_ing)
# Out:
# 38093

# %% [markdown]
# 38093 personas tienen un salario estrictamente mayor al salario mínimo(2.000.000 COP)

# %% [markdown]
# 3. Crea el dataframe df_mujeres donde se encuentren solamente mujeres que están ubicadas en el departamento del Tolima, que son asalariadas y cuyo nivel educativo es educación media o superior.

# %%
df_mujeres = df_empleo[(df_empleo['sexo'] == 'Mujer') &
                       (df_empleo['nombre_dpto'] == 'TOLIMA') &
                       (df_empleo['categoria_ocupacional'] == 'Asalariado') &
                       df_empleo['nivel_educativo'].isin(['Educación media', 'Técnica profesional', 'Tecnológica', 'Universitaria', 'Especialización', 'Maestría', 'Doctorado'])]
df_mujeres
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 204009      8373281         1           1    9
# 341096      8435212         1           1   11
# 83927       8323356         1           1    8
# 391232      8465937         1           2   12
# 226543      8383161         1           1   10
# ...             ...       ...         ...  ...
# 322795      8427566         1           4   11
# 260973      8397601         1           2   10
# 80586       8321923         1           2    8
# 328972      8430190         1           2   11
# 384668      8462959         1           3   12
#
#                                     clase departamento nombre_dpto  \
# 204009                          Cabeceras           73      TOLIMA
# 341096                          Cabeceras           73      TOLIMA
# 83927                           Cabeceras           73      TOLIMA
# 391232                          Cabeceras           73      TOLIMA
# 226543                          Cabeceras           73      TOLIMA
# ...                                   ...          ...         ...
# 322795                          Cabeceras           73      TOLIMA
# 260973  Centros poblados y rural disperso           73      TOLIMA
# 80586                           Cabeceras           73      TOLIMA
# 328972                          Cabeceras           73      TOLIMA
# 384668  Centros poblados y rural disperso           73      TOLIMA
#
#         factor_expansion  poblacion_total   sexo  edad  \
# 204009            309.84                1  Mujer    76
# 341096            379.47                1  Mujer    68
# 83927             407.65                1  Mujer    67
# 391232            310.36                1  Mujer    67
# 226543            285.20                1  Mujer    67
# ...                  ...              ...    ...   ...
# 322795            448.54                1  Mujer    18
# 260973          1,024.49                1  Mujer    18
# 80586             690.44                1  Mujer    18
# 328972            884.18                1  Mujer    18
# 384668          1,513.23                1  Mujer    17
#
#                      grupo_etnico      nivel_educativo  ocupados  \
# 204009  Ninguno de los anteriores      Educación media      1.00
# 341096  Ninguno de los anteriores  Técnica profesional      1.00
# 83927   Ninguno de los anteriores      Especialización      1.00
# 391232  Ninguno de los anteriores      Especialización      1.00
# 226543  Ninguno de los anteriores        Universitaria      1.00
# ...                           ...                  ...       ...
# 322795  Ninguno de los anteriores  Técnica profesional      1.00
# 260973  Ninguno de los anteriores      Educación media      1.00
# 80586   Ninguno de los anteriores      Educación media      1.00
# 328972  Ninguno de los anteriores      Educación media      1.00
# 384668  Ninguno de los anteriores      Educación media      1.00
#
#        categoria_ocupacional cod_ciiu  \
# 204009            Asalariado     8530
# 341096            Asalariado     6820
# 83927             Asalariado     8530
# 391232            Asalariado     8530
# 226543            Asalariado     8530
# ...                      ...      ...
# 322795            Asalariado     5611
# 260973            Asalariado     5613
# 80586             Asalariado     4711
# 328972            Asalariado     4755
# 384668            Asalariado     5611
#
#                                                 desc_ciiu  ingreso_laboral
# 204009  Establecimientos que combinan diferentes nivel...     1,423,500.00
# 341096  Actividades inmobiliarias realizadas a cambio ...       950,000.00
# 83927   Establecimientos que combinan diferentes nivel...     5,700,000.00
# 391232  Establecimientos que combinan diferentes nivel...     4,700,000.00
# 226543  Establecimientos que combinan diferentes nivel...     3,500,000.00
# ...                                                   ...              ...
# 322795           Expendio a la mesa de comidas preparadas       950,000.00
# 260973       Expendio de comidas preparadas en cafeterías     1,400,000.00
# 80586   Comercio al por menor en establecimientos no e...       960,000.00
# 328972  Comercio al por menor de artículos y utensilio...     1,400,000.00
# 384668           Expendio a la mesa de comidas preparadas     1,350,000.00
#
# [1137 rows x 18 columns]

# %% [markdown]
# 4. ¿Cuáles son las dimensiones de df_mujeres?

# %%
df_mujeres.shape
# Out:
# (1137, 18)
