# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelavasquezo/Trabajos-IA-/blob/main/Taller_importaci%C3%B3n_Dana_Mendoza_Manuela_Vasquez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller importación y extracción de datos

# %% [markdown]
# **Nombres estudiantes:**
#
# - Manuela Vásquez Osorio
# - Dana Melissa Mendoza Santiago

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# 1. Buscar la base de países del World Economic Outlook (WEO) del FMI, subirla a su drive y cargarla en el notebook concectándose a google drive

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive'
os.chdir(path)

# %%
weo = '/content/drive/MyDrive/datasets/weoapr2025all.xlsx'

# %%
#Primeras 5 filas
df = pd.read_excel(weo)
df.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
# ...

# %%
#Últimas 10 filas
df.tail(10)
# Out:
#                                        WEO Country Code  ISO WEO Subject Code  \
# 8616                                                698  ZWE     GGXONLB_NGDP
# 8617                                                698  ZWE           GGXWDN
# 8618                                                698  ZWE      GGXWDN_NGDP
# 8619                                                698  ZWE           GGXWDG
# 8620                                                698  ZWE      GGXWDG_NGDP
# 8621                                                698  ZWE          NGDP_FY
# 8622                                                698  ZWE              BCA
# 8623                                                698  ZWE        BCA_NGDPD
# 8624                                                NaN  NaN              NaN
# 8625  International Monetary Fund, World Economic Ou...  NaN              NaN
#
#        Country                                 Subject Descriptor  \
# ...

# %%
#3 Filas aleatorias
df.sample(3)
# Out:
#      WEO Country Code  ISO WEO Subject Code      Country  \
# 6602              942  SRB             NGDP       Serbia
# 7082              184  ESP              BCA        Spain
# 5457              196  NZL        NGDP_RPCH  New Zealand
#
#                            Subject Descriptor  \
# 6602   Gross domestic product, current prices
# 7082                  Current account balance
# 5457  Gross domestic product, constant prices
#
#                                           Subject Notes              Units  \
# 6602  Expressed in billions of national currency uni...  National currency
# 7082  Current account is all transactions other than...       U.S. dollars
# 5457  Annual percentages of constant price GDP are y...     Percent change
#
#          Scale                      Country/Series-specific Notes   1980  ...  \
# 6602  Billions  Source: National Statistics Office. Statistica...    NaN  ...
# 7082  Billions  Source: Central Bank Latest actual data: 2024 ...  -5300  ...
# ...

# %%
#Muestre de la fila 2 a la 5 y solamente la segunda columna
df.iloc[1:5, 1]
# Out:
# 1    AFG
# 2    AFG
# 3    AFG
# 4    AFG
# Name: ISO, dtype: object

# %%
#Use len() para saber cuántas filas tiene
len(df)
# Out:
# 8626

# %%
#Use .shape para saber el número de filas y columnas
df.shape
# Out:
# (8626, 61)

# %%
#Use .columns para ver el nombre de las columnas
df.columns
# Out:
# Index([             'WEO Country Code',                           'ISO',
#                     'WEO Subject Code',                       'Country',
#                   'Subject Descriptor',                 'Subject Notes',
#                                'Units',                         'Scale',
#        'Country/Series-specific Notes',                            1980,
#                                   1981,                            1982,
#                                   1983,                            1984,
#                                   1985,                            1986,
#                                   1987,                            1988,
#                                   1989,                            1990,
#                                   1991,                            1992,
#                                   1993,                            1994,
#                                   1995,                            1996,
# ...

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df.dtypes
# Out:
# WEO Country Code          object
# ISO                       object
# WEO Subject Code          object
# Country                   object
# Subject Descriptor        object
#                           ...
# 2027                      object
# 2028                      object
# 2029                      object
# 2030                      object
# Estimates Start After    float64
# Length: 61, dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8626 entries, 0 to 8625
# Data columns (total 61 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   WEO Country Code               8625 non-null   object
#  1   ISO                            8624 non-null   object
#  2   WEO Subject Code               8624 non-null   object
#  3   Country                        8624 non-null   object
#  4   Subject Descriptor             8624 non-null   object
#  5   Subject Notes                  8624 non-null   object
#  6   Units                          8624 non-null   object
#  7   Scale                          8624 non-null   object
#  8   Country/Series-specific Notes  7648 non-null   object
#  9   1980                           3861 non-null   object
#  10  1981                           3995 non-null   object
#  11  1982                           4039 non-null   object
# ...

# %% [markdown]
# 2. Conectarse a la API del Banco Mundial y traer datos de inflación para Colombia, Ecuador, Brasil, Chile, Mexico y Perú, años 2010-2023

# %%
# !pip install wbdata

# %%
import wbdata
import datetime
# !pip install wbdata --upgrade

# %%
wbdata.get_indicators(query="inflation", source=2)
# Out:
# id                    name
# --------------------  -------------------------------------------------
# FP.CPI.TOTL.ZG        Inflation, consumer prices (annual %)
# NY.GDP.DEFL.KD.ZG     Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)

# %%
indicador = {"FP.CPI.TOTL.ZG": "Inflación"}

# El orden es: año (2010), mes (1), día (1)
fecha_inicio = datetime.datetime(2010, 1, 1)
# El orden es: año (2023), mes (1), día (1)
fecha_fin = datetime.datetime(2023, 1, 1)

# Descargar datos
df1 = wbdata.get_dataframe(indicador, country= ["COL","ECU","BRA","CHL","MEX","PER"], date=(fecha_inicio, fecha_fin))

df1
# Out:
#               Inflación
# country date
# Brazil  2023   4.593563
#         2022   9.280106
#         2021   8.301660
#         2020   3.211768
#         2019   3.732976
# ...                 ...
# Peru    2014   3.411946
#         2013   2.767897
#         2012   3.611213
#         2011   3.369311
#         2010   1.528321
#
# [84 rows x 1 columns]

# %%
#Primeras 5 filas
df1.head()
# Out:
#               Inflación
# country date
# Brazil  2023   4.593563
#         2022   9.280106
#         2021   8.301660
#         2020   3.211768
#         2019   3.732976

# %%
#Últimas 10 filas
df1.tail(10)
# Out:
#               Inflación
# country date
# Peru    2019   2.252122
#         2018   1.509154
#         2017   2.994900
#         2016   3.557177
#         2015   3.398092
#         2014   3.411946
#         2013   2.767897
#         2012   3.611213
#         2011   3.369311
#         2010   1.528321

# %%
#3 Filas aleatorias
df1.sample(3)
# Out:
#               Inflación
# country date
# Brazil  2015   9.029901
# Ecuador 2016   1.728265
# Peru    2023   6.455613

# %%
#Muestre de la fila 2 a la 5 y solamente la segunda columna
df1.iloc[1:5, 0]
#El df solo tiene una columna, lo podemos ver con .shape, es por esto que se usa 0 para mostrar la única que hay. Si se intenta mostrar la segunda columa arroja un error
# Out:
# country  date
# Brazil   2022    9.280106
#          2021    8.301660
#          2020    3.211768
#          2019    3.732976
# Name: Inflación, dtype: float64

# %%
#Use len() para saber cuantas filas tiene
len(df1)
# Out:
# 84

# %%
#Use .shape para saber el número de filas y columnas
df1.shape
# Out:
# (84, 1)

# %%
#Use .columns para ver el nombre de las columnas
df1.columns
# Out:
# Index(['Inflación'], dtype='object')

# %%
#Use dtypes para saver el tipo de dato de cada columna
df1.dtypes
# Out:
# Inflación    float64
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df1.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# MultiIndex: 84 entries, ('Brazil', '2023') to ('Peru', '2010')
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Inflación  84 non-null     float64
# dtypes: float64(1)
# memory usage: 1.8+ KB

# %% [markdown]
# 3. Conectarse a la API del Banco Mundial y traer los siguientes datos para Alemania 2010-2023: crecimiento del PIB, PIB per cápita, tasa de inflación, tasa de desempleo y población.

# %%
indicador = {"NY.GDP.MKTP.KD.ZG": "Crecimiento del PIB","NY.GDP.PCAP.PP.CD": "PIB per cápita en PPA","FP.CPI.TOTL.ZG": "Tasa de inflación", "SL.UEM.TOTL.ZS":"Desempleo","SP.POP.TOTL":"Población"}

# El orden es: año (2010), mes (1), día (1)
fecha_inicio = datetime.datetime(2010, 1, 1)
# El orden es: año (2023), mes (1), día (1)
fecha_fin = datetime.datetime(2023, 1, 1)

# Descargar datos
df2 = wbdata.get_dataframe(indicador, country= ["DEU"], date=(fecha_inicio, fecha_fin))

df2
# Out:
#       Crecimiento del PIB  PIB per cápita en PPA  Tasa de inflación  \
# date
# 2023            -0.869648           71684.031188           5.946437
# 2022             1.809258           69048.988404           6.872574
# 2021             3.910000           62530.765320           3.066667
# 2020            -4.131914           58685.872700           0.144878
# 2019             0.977735           59270.727650           1.445660
# 2018             1.135696           56273.040563           1.732169
# 2017             2.797907           54110.253665           1.509495
# 2016             2.222222           51569.901684           0.491747
# 2015             1.663006           48545.400722           0.514426
# 2014             2.180186           47938.796821           0.906794
# 2013             0.396996           45889.017302           1.504723
# 2012             0.463512           44229.394192           2.008489
# 2011             3.757969           43398.344399           2.075173
# ...

# %%
#Primeras 5 filas
df2.head()
# Out:
#       Crecimiento del PIB  PIB per cápita en PPA  Tasa de inflación  \
# date
# 2023            -0.869648           71684.031188           5.946437
# 2022             1.809258           69048.988404           6.872574
# 2021             3.910000           62530.765320           3.066667
# 2020            -4.131914           58685.872700           0.144878
# 2019             0.977735           59270.727650           1.445660
#
#       Desempleo   Población
# date
# 2023      3.071  83287273.0
# 2022      3.137  83177813.0
# 2021      3.594  83196078.0
# 2020      3.881  83160871.0
# 2019      3.163  83092962.0

# %%
#Últimas 10 filas
df2.tail(10)
# Out:
#       Crecimiento del PIB  PIB per cápita en PPA  Tasa de inflación  \
# date
# 2019             0.977735           59270.727650           1.445660
# 2018             1.135696           56273.040563           1.732169
# 2017             2.797907           54110.253665           1.509495
# 2016             2.222222           51569.901684           0.491747
# 2015             1.663006           48545.400722           0.514426
# 2014             2.180186           47938.796821           0.906794
# 2013             0.396996           45889.017302           1.504723
# 2012             0.463512           44229.394192           2.008489
# 2011             3.757969           43398.344399           2.075173
# 2010             4.134638           39726.098692           1.103810
#
#       Desempleo   Población
# date
# 2019      3.163  83092962.0
# 2018      3.384  82905782.0
# 2017      3.781  82657002.0
# 2016      4.104  82348669.0
# 2015      4.612  81686611.0
# 2014      4.979  80982500.0
# ...

# %%
#3 filas aleatorias
df2.sample(3)
# Out:
#       Crecimiento del PIB  PIB per cápita en PPA  Tasa de inflación  \
# date
# 2011             3.757969           43398.344399           2.075173
# 2013             0.396996           45889.017302           1.504723
# 2022             1.809258           69048.988404           6.872574
#
#       Desempleo   Población
# date
# 2011      5.967  80274983.0
# 2013      5.316  80645605.0
# 2022      3.137  83177813.0

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df2.iloc[1:5, 1]
# Out:
# date
# 2022    69048.988404
# 2021    62530.765320
# 2020    58685.872700
# 2019    59270.727650
# Name: PIB per cápita en PPA, dtype: float64

# %%
#Use .len() para saber cuantas filas tiene
len(df2)
# Out:
# 14

# %%
#Use .shape para saber el numero de filas y columnas
df2.shape
# Out:
# (14, 5)

# %%
#Use .columns para ver el nombre de las columnas
df2.columns
# Out:
# Index(['Crecimiento del PIB', 'PIB per cápita en PPA', 'Tasa de inflación',
#        'Desempleo', 'Población'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df2.dtypes
# Out:
# Crecimiento del PIB      float64
# PIB per cápita en PPA    float64
# Tasa de inflación        float64
# Desempleo                float64
# Población                float64
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df2.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# Index: 14 entries, 2023 to 2010
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crecimiento del PIB    14 non-null     float64
#  1   PIB per cápita en PPA  14 non-null     float64
#  2   Tasa de inflación      14 non-null     float64
#  3   Desempleo              14 non-null     float64
#  4   Población              14 non-null     float64
# dtypes: float64(5)
# memory usage: 672.0+ bytes

# %% [markdown]
# 4. Traer dos conjuntos de datos de la página de datos abiertos del Gobierno de Colombia usando API. Los que le llamen la atención

# %%
import requests

# %%
url = "https://www.datos.gov.co/resource/2a76-5evx.json"

# Solicitud a la API
response = requests.get(url)
data = response.json()

# Convertir a DataFrame
df3 = pd.DataFrame(data)

df3.head()
# Out:
#     ano cod_etc    nombre_etc
# 0  2021    3819  Buenaventura
# 1  2020    3819  Buenaventura
# 2  2019    3819  Buenaventura
# 3  2018    3819  Buenaventura
# 4  2017    3819  Buenaventura

# %%
#Primeras 5 filas
df3.head()
# Out:
#     ano cod_etc    nombre_etc
# 0  2021    3819  Buenaventura
# 1  2020    3819  Buenaventura
# 2  2019    3819  Buenaventura
# 3  2018    3819  Buenaventura
# 4  2017    3819  Buenaventura

# %%
#Últimas 10 filas
df3.tail(10)
# Out:
#      ano cod_etc    nombre_etc
# 4   2017    3819  Buenaventura
# 5   2016    3819  Buenaventura
# 6   2015    3819  Buenaventura
# 7   2014    3819  Buenaventura
# 8   2013    3819  Buenaventura
# 9   2012    3819  Buenaventura
# 10  2011    3819  Buenaventura
# 11  2022    3819  Buenaventura
# 12  2023    3819  Buenaventura
# 13  2024    3819  Buenaventura

# %%
#3 filas aleatorias
df3.sample(3)
# Out:
#      ano cod_etc    nombre_etc
# 2   2019    3819  Buenaventura
# 10  2011    3819  Buenaventura
# 13  2024    3819  Buenaventura

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df3.iloc[2:6,1]
# Out:
# 2    3819
# 3    3819
# 4    3819
# 5    3819
# Name: cod_etc, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df3)
# Out:
# 14

# %%
#Use .shape para saber el numero de filas y columnas
df3.shape
# Out:
# (14, 3)

# %%
#Use .columns para ver el nombre de las columnas
df3.columns
# Out:
# Index(['ano', 'cod_etc', 'nombre_etc'], dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df3.dtypes
# Out:
# ano           object
# cod_etc       object
# nombre_etc    object
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ano         14 non-null     object
#  1   cod_etc     14 non-null     object
#  2   nombre_etc  14 non-null     object
# dtypes: object(3)
# memory usage: 468.0+ bytes

# %%
url = "https://www.datos.gov.co/resource/6z97-i2yt.json"

# Solicitud a la API
response = requests.get(url)
data = response.json()

# Convertir a DataFrame
df4 = pd.DataFrame(data)

df4.head()
# Out:
#   vigencia mes              rubro                                  concepto  \
# 0     2025   7                  0                    DISPONIBILIDAD INICIAL
# 1     2025   7  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 2     2025   7  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 3     2025   7  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 4     2025   7  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
#
#   presupuesto_vigente_pv   recaudos_rs    rs_pv
# 0           254497000000  160598462957   6310.0
# 1           773998900000  287869623233  3719.00
# 2             5824000000    2011507282  3454.00
# 3           246663000000  107113202118  4342.00
# 4             1407000000        137499     1.00

# %%
#Primeras 5 filas
df4.head()
# Out:
#   vigencia mes              rubro                                  concepto  \
# 0     2025   7                  0                    DISPONIBILIDAD INICIAL
# 1     2025   7  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 2     2025   7  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 3     2025   7  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 4     2025   7  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
#
#   presupuesto_vigente_pv   recaudos_rs    rs_pv
# 0           254497000000  160598462957   6310.0
# 1           773998900000  287869623233  3719.00
# 2             5824000000    2011507282  3454.00
# 3           246663000000  107113202118  4342.00
# 4             1407000000        137499     1.00

# %%
#Últimas 10 filas
df4.tail(10)
# Out:
#    vigencia mes              rubro                                  concepto  \
# 38     2025  11          2-05-1-03              VALORES DISTINTOS A ACCIONES
# 39     2025  11          2-15-1-03                         DE OTRAS EMPRESAS
# 40     2025  12                  0                    DISPONIBILIDAD INICIAL
# 41     2025  12  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 42     2025  12  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 43     2025  12  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 44     2025  12  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
# 45     2025  12  1-02-5-01-08-08-9            OTROS SERVICIOS DE FABRICACIÓN
# 46     2025  12          2-05-1-03              VALORES DISTINTOS A ACCIONES
# 47     2025  12          2-15-1-03                         DE OTRAS EMPRESAS
#
#    presupuesto_vigente_pv   recaudos_rs     rs_pv
# 38            20000000000   28734528549  14367.00
# ...

# %%
#3 filas aleatorias
df4.sample(3)
# Out:
#    vigencia mes              rubro                     concepto  \
# 10     2025   8  1-02-5-01-04-01-2  PRODUCTOS DE HIERRO Y ACERO
# 40     2025  12                  0       DISPONIBILIDAD INICIAL
# 20     2025   9  1-02-5-01-05-04-6   SERVICIOS DE INSTALACIONES
#
#    presupuesto_vigente_pv   recaudos_rs    rs_pv
# 10             5824000000    4504884603  7735.00
# 40           254497000000  160598462957   6310.0
# 20             1407000000        174233     1.00

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df4.iloc[2:6,1]
# Out:
# 2    7
# 3    7
# 4    7
# 5    7
# Name: mes, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df4)
# Out:
# 48

# %%
#Use .shape para saber el numero de filas y columnas
df4.shape
# Out:
# (48, 7)

# %%
#Use .columns para ver el nombre de las columnas
df4.columns
# Out:
# Index(['vigencia', 'mes', 'rubro', 'concepto', 'presupuesto_vigente_pv',
#        'recaudos_rs', 'rs_pv'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df4.dtypes
# Out:
# vigencia                  object
# mes                       object
# rubro                     object
# concepto                  object
# presupuesto_vigente_pv    object
# recaudos_rs               object
# rs_pv                     object
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   vigencia                48 non-null     object
#  1   mes                     48 non-null     object
#  2   rubro                   48 non-null     object
#  3   concepto                48 non-null     object
#  4   presupuesto_vigente_pv  48 non-null     object
#  5   recaudos_rs             48 non-null     object
#  6   rs_pv                   48 non-null     object
# dtypes: object(7)
# memory usage: 2.8+ KB

# %% [markdown]
# 5. Investigue otra página de donde pueda traer los datos mediante API y cargue el conjunto de datos en notebook

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 50,
    'page': 1
}

response = requests.get(url, params=params)
df5= pd.DataFrame(response.json())
df5
# Out:
#                                                    id      symbol  \
# 0                                             bitcoin         btc
# 1                                            ethereum         eth
# 2                                              tether        usdt
# 3                                         binancecoin         bnb
# 4                                              ripple         xrp
# 5                                            usd-coin        usdc
# 6                                              solana         sol
# 7                                                tron         trx
# 8                                        figure-heloc  figr_heloc
# 9                                            dogecoin        doge
# 10                                           whitebit         wbt
# 11                                               usds        usds
# 12                                            cardano         ada
# ...

# %%
#Primeras 5 filas
df5.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       71180.00
# 1  https://coin-images.coingecko.com/coins/images...        2080.55
# 2  https://coin-images.coingecko.com/coins/images...           1.00
# 3  https://coin-images.coingecko.com/coins/images...         648.00
# 4  https://coin-images.coingecko.com/coins/images...           1.41
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1425992334426                1            1425993404010  5.728301e+10
# 1   251453839190                2             251453839190  2.431761e+10
# 2   183911740439                3             189379070825  8.805857e+10
# ...

# %%
#Últimas 10 filas
df5.tail(10)
# Out:
#                                                    id symbol  \
# 40  blackrock-usd-institutional-digital-liquidity-...  buidl
# 41                                      hashnote-usyc   usyc
# 42                                                okb    okb
# 43                                         pi-network     pi
# 44                                          bittensor    tao
# 45                                               aave   aave
# 46                                                sky    sky
# 47                                            aster-2  aster
# 48                                     falcon-finance   usdf
# 49                                      global-dollar   usdg
#
#                                                  name  \
# 40  BlackRock USD Institutional Digital Liquidity ...
# 41                                        Circle USYC
# 42                                                OKB
# 43                                         Pi Network
# ...

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df5.iloc[1:5, 1]
# Out:
# 1     eth
# 2    usdt
# 3     bnb
# 4     xrp
# Name: symbol, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df5)
# Out:
# 50

# %%
#Use .shape para saber el numero de filas y columnas
df5.shape
# Out:
# (50, 26)

# %%
#Use .columns para ver el nombre de las columnas
df5.columns
# Out:
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df5.dtypes
# Out:
# id                                   object
# symbol                               object
# name                                 object
# image                                object
# current_price                       float64
# market_cap                            int64
# market_cap_rank                       int64
# fully_diluted_valuation               int64
# total_volume                        float64
# high_24h                            float64
# low_24h                             float64
# price_change_24h                    float64
# price_change_percentage_24h         float64
# market_cap_change_24h               float64
# market_cap_change_percentage_24h    float64
# circulating_supply                  float64
# total_supply                        float64
# max_supply                          float64
# ath                                 float64
# ath_change_percentage               float64
# ath_date                             object
# ...

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                50 non-null     object
#  1   symbol                            50 non-null     object
#  2   name                              50 non-null     object
#  3   image                             50 non-null     object
#  4   current_price                     50 non-null     float64
#  5   market_cap                        50 non-null     int64
#  6   market_cap_rank                   50 non-null     int64
#  7   fully_diluted_valuation           50 non-null     int64
#  8   total_volume                      50 non-null     float64
#  9   high_24h                          50 non-null     float64
#  10  low_24h                           50 non-null     float64
# ...
